# %%
import pandas
dData= pandas.read_csv("test.csv")
Data = pandas.read_csv("StocksInputData-0.csv")
#print(dData)
#dData.loc[dData.BSE_Index==513375]
Data.head()
#Data.loc[Data.BSEIndex==506076]
#dData.head()

1 = PromotorShareHoldings
2 = PledgedShareHoldings
3 = EquityCapital
4 = BookValue
5 = PERation
# Out:
#   BSEIndex            CompanyName  AAAAA  BBBB  EquityCapital  BookValue  \
# 0   513375      Carborundum Uni.*    1.0  1803          18.90      61.87
# 1   506076      Grindwell Norton     5.0  1803          55.36      88.77
# 2   504879      Orient Abrasives     1.0  1803          11.96      16.65
# 3   505412           Wendt India*   10.0  1803           2.00     545.38
# 4   534839  Eco Friendly Food Pr     1.0  1803          24.77       1.51
#
#    LastFySales  LastFyProfit    EPS  Divident  ...  PromotorShareHoldings  \
# 0      1576.23        143.48   7.59      2.25  ...                  42.40
# 1      1405.38        147.16  13.29      4.00  ...                  58.35
# 2       323.68         16.99   1.42      0.25  ...                  63.56
# 3       129.42         12.30  61.49     25.00  ...                  79.73
# 4         2.39          0.95   0.04      0.00  ...                  20.37
#
#    PledgedShareHoldings Blank4  Blank3  MarketCap   Blank2  52WeekLowHigh  \
# ...

# %%
#print(dData)

#Data.head()
#Data.loc[Data.BSEIndex==506076]
dData.head()
#dData.loc[dData.BSE_Index==513375]
dData.str(BSE_Index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-f8176d8b96b7> in <module>
#       5 dData.head()
#       6 #dData.loc[dData.BSE_Index==513375]
# ----> 7 dData.str(BSE_Index)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
coutn =  0 
cou =0
for i in l:
    print(i)
# Out:
# 0       513375
# 1       506076
# 2       504879
# 3       505412
# 4       534839
#          ...
# 4001    517514
# 4002    590031
# 4003    500133
# 4004    504028
# 4005    530431
# Name: BSEIndex, Length: 4006, dtype: object
# 0       18.90
# 1       55.36
# 2       11.96
# 3        2.00
# 4       24.77
#         ...
# 4001     7.40
# 4002     5.31
# 4003    15.39
# 4004     4.73
# 4005     3.50
# Name: EquityCapital, Length: 4006, dtype: float64

# %%
#Data.BSEIndex[0]
p=list(Data.loc[Data.BSEIndex==str(513375)].iloc[0])
p[4]
# Out:
# 18.9
